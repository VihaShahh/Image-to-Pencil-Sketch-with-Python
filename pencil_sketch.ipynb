# %% [markdown]
# <a href="https://colab.research.google.com/github/VihaShahh/Image-to-Pencil-Sketch-with-Python/blob/main/pencil_sketch.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Image to Pencil Sketch with Python**

# %%
from google.colab.patches import cv2_imshow
import cv2

image = cv2.imread("/content/vihh.jpg")
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=489x1122>
# -1

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=489x1122>
# -1

# %%
inverted_image = 255 - gray_image
cv2_imshow(inverted_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=489x1122>
# -1

# %%
blurred = cv2.GaussianBlur(inverted_image, (21, 21), 0)

# %%
inverted_blurred = 255 - blurred
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale=256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=489x1122>
# -1

# %%
cv2_imshow(image)

# Display the pencil sketch
cv2_imshow(pencil_sketch)

cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=489x1122>
# <PIL.Image.Image image mode=L size=489x1122>
# -1
